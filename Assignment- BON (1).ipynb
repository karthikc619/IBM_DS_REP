# %% [markdown]
# Introduction/Problem Statement:
#
# GTH is a global company headquartered in Thousand oaks for organizing events, currently it works on a project to organize an event for 4 days for a group of tourists from all over the world to visit New York city). The company must determine a good program, including a hotel of residence, a hall for meetings, places of landscape to visit, places of shopping, restaurants and cafes. The company must make a list of places in New York, including the nearest restaurants, cafes, and shopping stores. And it must provide respective maps in case the tourists can’t use his/her mobile application for any reason.
# I have been assigned with a task by my company to find the list of above-mentioned places and submit it for their final tour program.

# %% [markdown]
# Data Description:
#
# For this problem, we will get the services of Foursquare API to explore the data of New York City, in terms of their neighborhoods. The data also include the information about the places around each neighborhood like restaurants, hotels, coffee shops, parks, theater’s, art galleries, museums and many more. We will use machine learning technique, “Clustering” to segment the neighborhoods with similar objects based on each neighborhood data. This will help to locate the tourist’s areas and hubs.

# %% [markdown]
# Methodology:
# We are going to explore and visualize New York’s neighborhoods.
# Detailed description of execution:
# 1-	Import Libraries
# 2-	Define Foursquare Credentials
# 3-	Define New York city geography
# 4-	Search clean data frame for following items:
# •	Hotels
# •	Restaurants
# •	Places to visit (Parks, Museum, Art Gallery, Theater, Jazz Club)
# •	Shopping stores
# •	Cafeteria
# 5-	Using machine learning technique- Clustering will help company to plan an itinerary for tourists:
# •	Generate map to visualize hotels, shopping stores and cafeteria to show how they cluster together.
# •	Generate map to visualize park, Restaurant and cafeteria stores to show how they cluster together.
# •	Generate map to visualize Museum, Art Gallery, Restaurant and Cafeteria to show how they cluster together.
# •	Generate map to visualize Theater, Clubs and Restaurant to show how they cluster together.

# %% [markdown]
# STEP 1- IMPORTING ALL REQUIRED LIBRARIES TO USED IN THIS PROJECT

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

import csv # implements classes to read and write tabular data in CSV form

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2019.6.16  |       hecc5488_0         145 KB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     certifi-2019.6.16          |           py36_1         149 KB  conda-forge
#     openssl-1.1.1c             |       h516909a_0         2.1 MB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0         conda-forge
#     geopy:           1.20.0-py_0       conda-forge
#
# ...

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
from PIL import Image # converting images into arrays

# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0

# install wordcloud
# !conda install -c conda-forge wordcloud==1.4.1 --yes

# import package and its set of stopwords
from wordcloud import WordCloud, STOPWORDS

print ('Wordcloud is installed and imported!')
# Out:
# Matplotlib version:  3.0.2
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - wordcloud==1.4.1
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     wordcloud-1.4.1            |           py36_0         324 KB  conda-forge
#
# The following NEW packages will be INSTALLED:
#
#     wordcloud: 1.4.1-py36_0 conda-forge
#
#
# ...
# wordcloud-1.4.1      | 324 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Wordcloud is installed and imported!

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import matplotlib.ticker as ticker

# notice: installing seaborn might takes a few minutes
# !conda install -c anaconda seaborn -y
import seaborn as sns

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1              |       h7b6447c_0         5.0 MB  anaconda
#     seaborn-0.9.0              |           py36_0         379 KB  anaconda
#     ca-certificates-2019.5.15  |                0         133 KB  anaconda
#     certifi-2019.6.16          |           py36_0         154 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         5.7 MB
#
# The following packages will be UPDATED:
#
#     openssl:         1.1.1c-h516909a_0    conda-forge --> 1.1.1-h7b6447c_0 anaconda
# ...

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt

# import k-means from clustering stage
from sklearn.cluster import KMeans

from sklearn.metrics import silhouette_score

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# # All requested packages already installed.
#
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# STEP 2- DEFINING FOURSQUARE CREDENTIALS

# %%
ClIENT_ID = 'MPT43K2CE4TIK1R40RWQ0HELP5HINYAZI4SHLXCZZJDA50VF' # your Foursquare ID
ClIENT_SECRET = 'TNYKF1QMC4AG3JIXK0M3WU1PYC1HD5VDWIP3RTXDFRLG2EAC' # your Foursquare Secret
VERSION = '20180604'
LIMIT =60
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: MPT43K2CE4TIK1R40RWQ0HELP5HINYAZI4SHLXCZZJDA50VF
# Foursquare_Secret:TNYKF1QMC4AG3JIXK0M3WU1PYC1HD5VDWIP3RTXDFRLG2EAC

# %% [markdown]
# STEP 3- DOWNLOAD & EXPLORE NEW YORK GEO COORDINATES DATASET

# %%
# !wget -q -O 'newyork_data.json' https://ibm.box.com/shared/static/fbpwbovar7lf8p5sgddm06cgipa2rxpe.json
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
neighborhoods_data = newyork_data['features']

# %%
neighborhoods_data[0]
# Out:
# {'type': 'Feature',
#  'id': 'nyu_2451_34572.1',
#  'geometry': {'type': 'Point',
#   'coordinates': [-73.84720052054902, 40.89470517661]},
#  'geometry_name': 'geom',
#  'properties': {'name': 'Wakefield',
#   'stacked': 1,
#   'annoline1': 'Wakefield',
#   'annoline2': None,
#   'annoline3': None,
#   'annoangle': 0.0,
#   'borough': 'Bronx',
#   'bbox': [-73.84720052054902,
#    40.89470517661,
#    -73.84720052054902,
#    40.89470517661]}}

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %%
neighborhoods
# Out:
# Empty DataFrame
# Columns: [Borough, Neighborhood, Latitude, Longitude]
# Index: []

# %%
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
neighborhoods.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(neighborhoods['Borough'].unique()),
        neighborhoods.shape[0]
    )
)
# Out:
# The dataframe has 5 boroughs and 306 neighborhoods.

# %%
# define the city and get its latitude & longitude 
city = 'New York'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7127281 -74.0060152

# %%
# create map of Toronto using latitude and longitude values
map_NewYork = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_NewYork)  
    
map_NewYork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# STEP 4- EXPLORE AND CLEAN DATA FOR FOLLOWING ITEMS:

# %% [markdown]
# A) HOTELS

# %%
# search for hotels
search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=MPT43K2CE4TIK1R40RWQ0HELP5HINYAZI4SHLXCZZJDA50VF&client_secret=TNYKF1QMC4AG3JIXK0M3WU1PYC1HD5VDWIP3RTXDFRLG2EAC&ll=40.7127281,-74.0060152&v=20180604&query=Hotel&radius=500&limit=60'

# %%
# Send the GET Request and examine the results
results = requests.get(url).json()
#results

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...         NaN
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...         NaN
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...         NaN
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...         NaN
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...         NaN
#
#   delivery.provider.icon.name delivery.provider.icon.prefix  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.name delivery.url  hasPerk  \
# 0                          NaN                    NaN          NaN    False
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                                    name categories        address  cc  \
# 0                           Smyth Hotel      Hotel  85 W Broadway  US
# 1  Four Seasons Hotel New York Downtown      Hotel  27 Barclay St  US
# 2                    Duane Street Hotel      Hotel   130 Duane St  US
# 3        The Beekman - A Thompson Hotel      Hotel  123 Nassau St  US
# 4                         Artezen Hotel      Hotel     24 John St  US
#
#        city        country    crossStreet  distance  \
# 0  New York  United States    Chambers St       379
# 1  New York  United States       Broadway       284
# 2  New York  United States      Church St       368
# 3  New York  United States  at Beekman St       182
# 4  New York  United States            NaN       411
#
#                                     formattedAddress  \
# 0  [85 W Broadway (Chambers St), New York, NY 100...
# 1  [27 Barclay St (Broadway), New York, NY 10007,...
# 2  [130 Duane St (Church St), New York, NY 10013,...
# ...

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2
# Out:
#                                                  name  \
# 0                                         Smyth Hotel
# 1                Four Seasons Hotel New York Downtown
# 2                                  Duane Street Hotel
# 3                      The Beekman - A Thompson Hotel
# 4                                       Artezen Hotel
# 5                        Cosmopolitan Hotel - TriBeCa
# 6                                     Frederick Hotel
# 7          Spa @ Four Seasons Hotel New York Downtown
# 8                        Beekman Hotel Fitness Center
# 9                                 The Frederick Hotel
# 10  Fitness Center @ Four Seasons Hotel New York D...
# 11                                  Millennium Hilton
# 12                            Moxy Hotel Fitness Room
# 13                                    The Angel Hotel
# 14                            Millenium Baileys Hotel
# 15                           Sheraton Frankfurt hotel
# ...

# %%
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                                      name            categories  \
# 0                             Smyth Hotel                 Hotel
# 1    Four Seasons Hotel New York Downtown                 Hotel
# 2                      Duane Street Hotel                 Hotel
# 3          The Beekman - A Thompson Hotel                 Hotel
# 4                           Artezen Hotel                 Hotel
# 5            Cosmopolitan Hotel - TriBeCa                 Hotel
# 6                         Frederick Hotel                 Hotel
# 8            Beekman Hotel Fitness Center  Gym / Fitness Center
# 9                     The Frederick Hotel                 Hotel
# 11                      Millennium Hilton                 Hotel
# 18           The Bar Room at Temple Court             Hotel Bar
# 20                           Temple Court   American Restaurant
# 22                              The Odeon     French Restaurant
# 23                 The James Hotel [FiDi]                 Hotel
# ...

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                      name categories  \
# 0                             Smyth Hotel      Hotel
# 1    Four Seasons Hotel New York Downtown      Hotel
# 2                      Duane Street Hotel      Hotel
# 3          The Beekman - A Thompson Hotel      Hotel
# 4                           Artezen Hotel      Hotel
# 5            Cosmopolitan Hotel - TriBeCa      Hotel
# 6                         Frederick Hotel      Hotel
# 9                     The Frederick Hotel      Hotel
# 11                      Millennium Hilton      Hotel
# 23                 The James Hotel [FiDi]      Hotel
# 24                              Gild Hall      Hotel
# 25  Holiday Inn New York City-Wall Street      Hotel
#
#                        address        lat        lng postalCode state
# 0                85 W Broadway  40.715144 -74.009183      10007    NY
# 1                27 Barclay St  40.712612 -74.009380      10007    NY
# ...

# %%
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                                      name categories  \
# 0                             Smyth Hotel      Hotel
# 1    Four Seasons Hotel New York Downtown      Hotel
# 2                      Duane Street Hotel      Hotel
# 3          The Beekman - A Thompson Hotel      Hotel
# 4                           Artezen Hotel      Hotel
# 5            Cosmopolitan Hotel - TriBeCa      Hotel
# 6                         Frederick Hotel      Hotel
# 9                     The Frederick Hotel      Hotel
# 11                      Millennium Hilton      Hotel
# 23                 The James Hotel [FiDi]      Hotel
# 24                              Gild Hall      Hotel
# 25  Holiday Inn New York City-Wall Street      Hotel
#
#                        address        lat        lng postalCode state
# 0                85 W Broadway  40.715144 -74.009183      10007    NY
# 1                27 Barclay St  40.712612 -74.009380      10007    NY
# ...

# %%
df_hotel = df_hotels[df_hotels.postalCode == '10007']
df_hotel
# Out:
#                                     name categories           address  \
# 0                            Smyth Hotel      Hotel     85 W Broadway
# 1   Four Seasons Hotel New York Downtown      Hotel     27 Barclay St
# 5           Cosmopolitan Hotel - TriBeCa      Hotel     95 W Broadway
# 6                        Frederick Hotel      Hotel     95 W Broadway
# 9                    The Frederick Hotel      Hotel  95 West Broadway
# 11                     Millennium Hilton      Hotel      55 Church St
#
#           lat        lng postalCode state
# 0   40.715144 -74.009183      10007    NY
# 1   40.712612 -74.009380      10007    NY
# 5   40.715622 -74.009115      10007    NY
# 6   40.715675 -74.009047      10007    NY
# 9   40.715460 -74.009383      10007    NY
# 11  40.711114 -74.010333      10007    NY

# %% [markdown]
# B) PARKS

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=MPT43K2CE4TIK1R40RWQ0HELP5HINYAZI4SHLXCZZJDA50VF&client_secret=TNYKF1QMC4AG3JIXK0M3WU1PYC1HD5VDWIP3RTXDFRLG2EAC&ll=40.7127281,-74.0060152&v=20180604&query=Park&radius=10000&limit=60'

# %%
# Send the GET Request and examine the results
presults = requests.get(url).json()
#presults

# %%
# assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...         NaN
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...         NaN
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...         NaN
# 3  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...         NaN
# 4  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...         NaN
#
#   delivery.provider.icon.name delivery.provider.icon.prefix  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.name delivery.url  \
# 0                          NaN                    NaN          NaN
# 1                          NaN                    NaN          NaN
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                    name categories                     address  cc      city  \
# 0  Brooklyn Bridge Park       Park                     Main St  US  Brooklyn
# 1          Battery Park       Park                  Battery Pl  US  New York
# 2        City Hall Park       Park                 17 Park Row  US  New York
# 3     Union Square Park       Park  btwn Broadway & Union Sq E  US  New York
# 4          Central Park       Park         59th St to 110th St  US  New York
#
#          country                   crossStreet  distance  \
# 0  United States                   Plymouth St      1415
# 1  United States                   at State St      1342
# 2  United States     btwn Broadway & Centre St        69
# 3  United States       btwn E 14th & E 17th St      2826
# 4  United States  5th Ave to Central Park West      8668
#
#                                     formattedAddress  \
# 0  [Main St (Plymouth St), Brooklyn, NY 11201, Un...
# ...

# %%
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                               name               categories  \
# 0                             Brooklyn Bridge Park                     Park
# 1                                     Battery Park                     Park
# 2                                   City Hall Park                     Park
# 3                                Union Square Park                     Park
# 4                                     Central Park                     Park
# 5                           Washington Square Park                     Park
# 6                                      Bryant Park                     Park
# 7                      Pier 25 - Hudson River Park                     Park
# 8                              Madison Square Park                     Park
# 9                                    Prospect Park                     Park
# 10                     Pier 26 - Hudson River Park                     Park
# ...

# %%
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                            name categories        address  \
# 0                          Brooklyn Bridge Park       Park        Main St
# 6                                   Bryant Park       Park      E 42nd St
# 21                             Bella Abzug Park       Park    Hudson Blvd
# 38    NY Waterway Ferry - Battery Park Terminal       Pier  North End Ave
# 40  New York Public Library - Battery Park City    Library  175 N End Ave
#
#           lat        lng         neighborhood postalCode state
# 0   40.702282 -73.996456  DUMBO, Brooklyn, NY      11201    NY
# 6   40.753621 -73.983265              Midtown      10018    NY
# 21  40.755580 -74.000344         Hudson Yards      10001    NY
# 38  40.714966 -74.017780    Battery Park City      10282    NY
# 40  40.715758 -74.015603    Battery Park City      10282    NY

# %%
# delete rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                     name categories      address        lat        lng  \
# 0   Brooklyn Bridge Park       Park      Main St  40.702282 -73.996456
# 6            Bryant Park       Park    E 42nd St  40.753621 -73.983265
# 21      Bella Abzug Park       Park  Hudson Blvd  40.755580 -74.000344
#
#            neighborhood postalCode state
# 0   DUMBO, Brooklyn, NY      11201    NY
# 6               Midtown      10018    NY
# 21         Hudson Yards      10001    NY

# %% [markdown]
# C)RESTAURANTS

# %%
# search for Restaurants
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=MPT43K2CE4TIK1R40RWQ0HELP5HINYAZI4SHLXCZZJDA50VF&client_secret=TNYKF1QMC4AG3JIXK0M3WU1PYC1HD5VDWIP3RTXDFRLG2EAC&ll=40.7127281,-74.0060152&v=20180604&query=Restaurant&radius=10000&limit=60'

# %%
# Send the GET Request and examine the results
Rresults = requests.get(url).json()
#Rresults

# %%
# assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...         NaN
# 1  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...      296411
# 2  [{'id': '4bf58dd8d48988d14c941735', 'name': 'W...      299726
# 3  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...         NaN
# 4  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...         NaN
#
#                 delivery.provider.icon.name  \
# 0                                       NaN
# 1  /delivery_provider_seamless_20180129.png
# 2  /delivery_provider_seamless_20180129.png
# 3                                       NaN
# 4                                       NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 2  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                               name          categories          address  cc  \
# 0        O'Hara's Restaurant & Pub                 Pub     120 Cedar St  US
# 1       Jing Fong Restaurant 金豐大酒樓  Dim Sum Restaurant  20 Elizabeth St  US
# 2  Mudville Restaurant & Tap House         Wings Joint  126 Chambers St  US
# 3   Golden Unicorn Restaurant 麒麟金閣  Dim Sum Restaurant    18 E Broadway  US
# 4          Bo Ky Restaurant 波記潮州小食  Chinese Restaurant     80 Bayard St  US
#
#        city        country                  crossStreet  distance  \
# 0  New York  United States             at Greenwich St.       656
# 1  New York  United States       btwn Bayard & Canal St       821
# 2  New York  United States  btwn W Broadway & Church St       377
# 3  New York  United States              at Catherine St       748
# 4  New York  United States                   at Mott St       702
#
#                                     formattedAddress  \
# 0  [120 Cedar St (at Greenwich St.), New York, NY...
# ...

# %%
# delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                                  name  \
# 0                           O'Hara's Restaurant & Pub
# 1                          Jing Fong Restaurant 金豐大酒樓
# 2                     Mudville Restaurant & Tap House
# 3                      Golden Unicorn Restaurant 麒麟金閣
# 4                             Bo Ky Restaurant 波記潮州小食
# 5                                  Waverly Restaurant
# 6                        TJ Byrnes Bar and Restaurant
# 7                               New Shezan Restaurant
# 8                           Hop Shing Restaurant 合誠茶樓
# 9                                    Galli Restaurant
# 10                         Deluxe Green Bo Restaurant
# 11                                  Puglia Restaurant
# 12                         Chatham Seafood Restaurant
# 13                             Sun Sai Gai Restaurant
# 14                           Amore's Pizza Restaurant
# 15                      Nam Son Vietnamese Restaurant
# ...

# %%
# delete rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                                  name  \
# 0                           O'Hara's Restaurant & Pub
# 1                          Jing Fong Restaurant 金豐大酒樓
# 2                     Mudville Restaurant & Tap House
# 3                      Golden Unicorn Restaurant 麒麟金閣
# 4                             Bo Ky Restaurant 波記潮州小食
# 5                                  Waverly Restaurant
# 6                        TJ Byrnes Bar and Restaurant
# 7                               New Shezan Restaurant
# 8                           Hop Shing Restaurant 合誠茶樓
# 9                                    Galli Restaurant
# 10                         Deluxe Green Bo Restaurant
# 11                                  Puglia Restaurant
# 12                         Chatham Seafood Restaurant
# 13                             Sun Sai Gai Restaurant
# 14                           Amore's Pizza Restaurant
# 15                      Nam Son Vietnamese Restaurant
# ...

# %% [markdown]
# D) CAFETERIA

# %%
# search for Cafeteria
search_query = 'Cafeteria'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=MPT43K2CE4TIK1R40RWQ0HELP5HINYAZI4SHLXCZZJDA50VF&client_secret=TNYKF1QMC4AG3JIXK0M3WU1PYC1HD5VDWIP3RTXDFRLG2EAC&ll=40.7127281,-74.0060152&v=20180604&query=Cafeteria&radius=10000&limit=60'

# %%
# Send the GET Request and examine the results
cresults = requests.get(url).json()
#cresults

# %%
# assign relevant part of JSON to venues
venues = cresults['response']['venues']

# tranform venues into a dataframe
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '54f4ba06498e2cf5561da814', 'name': 'C...         NaN
# 1  [{'id': '54f4ba06498e2cf5561da814', 'name': 'C...         NaN
# 2  [{'id': '54f4ba06498e2cf5561da814', 'name': 'C...         NaN
# 3  [{'id': '4bf58dd8d48988d157941735', 'name': 'N...       83278
# 4  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...         NaN
#
#                 delivery.provider.icon.name  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3  /delivery_provider_seamless_20180129.png
# 4                                       NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1                                       NaN                          NaN
# 2                                       NaN                          NaN
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head(10)
# Out:
#                                                 name               categories  \
# 0                      American Express HQ Cafeteria      Corporate Cafeteria
# 1                      Spotify Cafeteria Hub - FL 60      Corporate Cafeteria
# 2                            Goldman Sachs Cafeteria      Corporate Cafeteria
# 3                                          Cafeteria  New American Restaurant
# 4                                     Citi Cafeteria                     Café
# 5                      Spotify Cafeteria Hub - FL 70             Food Service
# 6  Cafeteria - Borough of Manhattan Community Col...        College Cafeteria
# 7                                    Condé Cafeteria      Corporate Cafeteria
# 8                            Deutsche Bank Cafeteria      Corporate Cafeteria
# 9                      Spotify Cafeteria Hub - FL 64      Corporate Cafeteria
#
#                   address  cc      city        country     crossStreet  \
# ...

# %%
# delete unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                                  name  \
# 0                       American Express HQ Cafeteria
# 1                       Spotify Cafeteria Hub - FL 60
# 2                             Goldman Sachs Cafeteria
# 3                                           Cafeteria
# 4                                      Citi Cafeteria
# 5                       Spotify Cafeteria Hub - FL 70
# 6   Cafeteria - Borough of Manhattan Community Col...
# 7                                     Condé Cafeteria
# 8                             Deutsche Bank Cafeteria
# 9                       Spotify Cafeteria Hub - FL 64
# 10                                 Whole Foods Market
# 11  New York Marriott Downtown - The Exchange Cafe...
# 12                           New York Times Cafeteria
# 13                                      FIT Cafeteria
# 14                              Fat Denny’s Cafeteria
# 15                      Spotify Cafeteria Hub - FL 67
# ...

# %%
# delete rows with none values
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                     name           categories               address  \
# 10    Whole Foods Market        Grocery Store  270 Greenwich Street
# 18  BNY Mellon Cafeteria                 Café        101 Barclay St
# 27  Condé Nast Cafeteria  Corporate Cafeteria     1 World Trade Ctr
#
#           lat        lng neighborhood postalCode state
# 10  40.715579 -74.011368      Tribeca      10007    NY
# 18  40.714288 -74.011757      Tribeca      10007    NY
# 27  40.756480 -73.985590       Financ      10007    NY

# %% [markdown]
# E) SHOPPING CENTER

# %%
# search for Shopping
search_query = 'Mall'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=MPT43K2CE4TIK1R40RWQ0HELP5HINYAZI4SHLXCZZJDA50VF&client_secret=TNYKF1QMC4AG3JIXK0M3WU1PYC1HD5VDWIP3RTXDFRLG2EAC&ll=40.7127281,-74.0060152&v=20180604&query=Mall&radius=1000&limit=60'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Mall_dataframe = json_normalize(venues)
Mall_dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...      383517
# 1  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...         NaN
# 2  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...         NaN
# 3  [{'id': '4bf58dd8d48988d111951735', 'name': 'J...         NaN
# 4  [{'id': '4bf58dd8d48988d1e0941735', 'name': 'H...         NaN
#
#                 delivery.provider.icon.name  \
# 0  /delivery_provider_seamless_20180129.png
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 1                                       NaN                          NaN
# 2                                       NaN                          NaN
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
Mall_clean_columns = ['name', 'categories'] + [col for col in Mall_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Mall_dataframe = Mall_dataframe.loc[:,Mall_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Mall_dataframe['categories'] = clean_Mall_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Mall_dataframe.columns = [column.split('.')[-1] for column in clean_Mall_dataframe.columns]

clean_Mall_dataframe.head(15)
# Out:
#                                                  name           categories  \
# 0                        Westfield World Trade Center        Shopping Mall
# 1                           South Street Seaport Mall        Shopping Mall
# 2                                  East Broadway Mall        Shopping Mall
# 3            Lux Accessories @ Shop Small Pop-Up Mall        Jewelry Store
# 4                                South Street Seaport      Harbor / Marina
# 5                                    Smith haven mall        Shopping Mall
# 6                                      Allen Mall One                 Park
# 7                                    brooksfield Mall        Shopping Mall
# 8                                    Allen Mall Three                 Park
# 9                             Nyc Mini Mall Gift Shop            Gift Shop
# 10                                    Allen Mall Four                 Park
# ...

# %%
# delete unnecessary columns
clean_Mall_dataframe2= clean_Mall_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Mall_dataframe2
# Out:
#                                                  name              categories  \
# 0                        Westfield World Trade Center           Shopping Mall
# 1                           South Street Seaport Mall           Shopping Mall
# 2                                  East Broadway Mall           Shopping Mall
# 3            Lux Accessories @ Shop Small Pop-Up Mall           Jewelry Store
# 4                                South Street Seaport         Harbor / Marina
# 5                                    Smith haven mall           Shopping Mall
# 6                                      Allen Mall One                    Park
# 7                                    brooksfield Mall           Shopping Mall
# 8                                    Allen Mall Three                    Park
# 9                             Nyc Mini Mall Gift Shop               Gift Shop
# 10                                    Allen Mall Four                    Park
# ...

# %%
# delete rows which its category is not Shopping Mall
df_Mall = clean_Mall_dataframe2[clean_Mall_dataframe2.categories == 'Shopping Mall']
df_Mall
# Out:
#                             name     categories           address        lat  \
# 0   Westfield World Trade Center  Shopping Mall  185 Greenwich St  40.711602
# 1      South Street Seaport Mall  Shopping Mall      19 Fulton St  40.706959
# 2             East Broadway Mall  Shopping Mall     88 E Broadway  40.713915
# 5               Smith haven mall  Shopping Mall               NaN  40.709730
# 7               brooksfield Mall  Shopping Mall               NaN  40.710690
# 15        Shop Small Pop-Up Mall  Shopping Mall               NaN  40.713128
# 18                   Mall Street  Shopping Mall               NaN  40.704462
#
#           lng postalCode state
# 0  -74.011368      10007    NY
# 1  -74.003798      10038    NY
# 2  -73.994290      10002    NY
# 5  -74.011810        NaN    NY
# 7  -74.015957        NaN    NY
# 15 -74.013369      10280    NY
# 18 -74.010893      10004    NY

# %% [markdown]
# F) THEATER

# %%
# search for Theater
search_query = 'Theater'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=MPT43K2CE4TIK1R40RWQ0HELP5HINYAZI4SHLXCZZJDA50VF&client_secret=TNYKF1QMC4AG3JIXK0M3WU1PYC1HD5VDWIP3RTXDFRLG2EAC&ll=40.7127281,-74.0060152&v=20180604&query=Theater&radius=1000&limit=60'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Theater_dataframe = json_normalize(venues)
Theater_dataframe.head()
# Out:
#                                           categories  events.count  \
# 0  [{'id': '4bf58dd8d48988d137941735', 'name': 'T...           NaN
# 1  [{'id': '4bf58dd8d48988d1e5931735', 'name': 'M...           NaN
# 2  [{'id': '4bf58dd8d48988d17f941735', 'name': 'M...           8.0
# 3  [{'id': '4bf58dd8d48988d1ac941735', 'name': 'C...           NaN
# 4  [{'id': '4bf58dd8d48988d11e941735', 'name': 'C...           NaN
#
#   events.summary  hasPerk                        id  \
# 0            NaN    False  4ea89e6702d5b8174e85e65e
# 1            NaN    False  4b032755f964a5200f4d22e3
# 2       8 movies    False  57218ba5498eb662eaa1e121
# 3            NaN    False  4bf470e194af2d7f0a9e3a72
# 4            NaN    False  4be070a3652b0f47c7727211
#
#             location.address location.cc location.city location.country  \
# 0               20 Thomas St          US      New York    United States
# 1  32 Avenue of the Americas          US      New York    United States
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
Theater_clean_columns = ['name', 'categories'] + [col for col in Theater_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Theater_dataframe = Theater_dataframe.loc[:,Theater_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Theater_dataframe['categories'] = clean_Theater_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Theater_dataframe.columns = [column.split('.')[-1] for column in clean_Theater_dataframe.columns]

clean_Theater_dataframe.head(15)
# Out:
#                                 name       categories  \
# 0   20 Thomas St. (The Flea Theater)          Theater
# 1                iHeartRadio Theater      Music Venue
# 2     iPic Theaters at Fulton Market    Movie Theater
# 3          Schaeberle Studio Theater  College Theater
# 4                        Theater Bar     Cocktail Bar
# 5               Royal Theater Cinema    Movie Theater
# 6                  Time Inc. Theater     Amphitheater
# 7    The Drama League Theater Center          Theater
# 8                     Nevada Theater        Multiplex
# 9      Regal Cinemas Battery Park 11    Movie Theater
# 10                 St Venice Theater       Strip Club
# 11  Russian American Musical Theater     Concert Hall
# 12                     Galli Theater          Theater
# 13               See Forever Theater          Theater
# 14                     accss theater          Theater
#
#                       address  cc      city        country  \
# ...

# %%
# delete unnecessary columns
clean_Theater_dataframe2= clean_Theater_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Theater_dataframe2
# Out:
#                                     name             categories  \
# 0       20 Thomas St. (The Flea Theater)                Theater
# 1                    iHeartRadio Theater            Music Venue
# 2         iPic Theaters at Fulton Market          Movie Theater
# 3              Schaeberle Studio Theater        College Theater
# 4                            Theater Bar           Cocktail Bar
# 5                   Royal Theater Cinema          Movie Theater
# 6                      Time Inc. Theater           Amphitheater
# 7        The Drama League Theater Center                Theater
# 8                         Nevada Theater              Multiplex
# 9          Regal Cinemas Battery Park 11          Movie Theater
# 10                     St Venice Theater             Strip Club
# 11      Russian American Musical Theater           Concert Hall
# 12                         Galli Theater                Theater
# 13                   See Forever Theater                Theater
# ...

# %%
df_Theater = clean_Theater_dataframe2[clean_Theater_dataframe2.categories == 'Theater']
df_Theater
# Out:
#                                 name categories                    address  \
# 0   20 Thomas St. (The Flea Theater)    Theater               20 Thomas St
# 7    The Drama League Theater Center    Theater  32 Avenue of the Americas
# 12                     Galli Theater    Theater                89 South St
# 13               See Forever Theater    Theater                        NaN
# 14                     accss theater    Theater                        NaN
# 15   Collective: Unconscious Theater    Theater              279 Church St
# 16                    Bowery Theater    Theater                  45 Bowery
# 18               Murray Khan Theater    Theater                        NaN
# 27      Manhattan Children's Theatre    Theater          380 Broadway Fl 4
#
#           lat        lng postalCode state
# 0   40.716161 -74.005826      10007    NY
# 7   40.720054 -74.004339      10013    NY
# 12  40.708816 -74.004786      10038    NY
# 13  40.712983 -74.013107      10007    NY
# ...

# %% [markdown]
# G) MUSEUM

# %%
# search for Museum
search_query = 'Museum'
radius = 3000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=MPT43K2CE4TIK1R40RWQ0HELP5HINYAZI4SHLXCZZJDA50VF&client_secret=TNYKF1QMC4AG3JIXK0M3WU1PYC1HD5VDWIP3RTXDFRLG2EAC&ll=40.7127281,-74.0060152&v=20180604&query=Museum&radius=3000&limit=60'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Museum_dataframe = json_normalize(venues)
Museum_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '5642206c498e4bfca532186c', 'name': 'M...    False
# 1  [{'id': '4bf58dd8d48988d18f941735', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d190941735', 'name': 'H...    False
# 3  [{'id': '4bf58dd8d48988d190941735', 'name': 'H...    False
# 4  [{'id': '4bf58dd8d48988d181941735', 'name': 'M...    False
#
#                          id  location.address location.cc location.city  \
# 0  4b6b5abff964a520fb022ce3  180 Greenwich St          US      New York
# 1  421a7600f964a5209d1f1fe3  99 Gansevoort St          US      New York
# 2  49d4bb1bf964a5204b5c1fe3     36 Battery Pl          US      New York
# 3  4e70a36d922e8e01baadf45c  180 Greenwich St          US      New York
# 4  45719c4bf964a520693e1fe3     1 Bowling Grn          US      New York
#
#   location.country           location.crossStreet  location.distance  \
# 0    United States       btwn Liberty & Fulton St                641
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
Museum_clean_columns = ['name', 'categories'] + [col for col in Museum_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Museum_dataframe = Museum_dataframe.loc[:,Museum_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Museum_dataframe['categories'] = clean_Museum_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Museum_dataframe.columns = [column.split('.')[-1] for column in clean_Museum_dataframe.columns]

clean_Museum_dataframe.head(15)
# Out:
#                                          name      categories  \
# 0     National September 11 Memorial & Museum   Memorial Site
# 1              Whitney Museum of American Art      Art Museum
# 2                   Museum of Jewish Heritage  History Museum
# 3       National September 11 Memorial Museum  History Museum
# 4      National Museum of the American Indian          Museum
# 5                                  New Museum      Art Museum
# 6         Museum of Chinese in America (MOCA)  History Museum
# 7             Ellis Island Immigration Museum  History Museum
# 8                             Tenement Museum  History Museum
# 9   Leslie+Lohman Museum of Gay & Lesbian Art     Art Gallery
# 10                South Street Seaport Museum  History Museum
# 11                        Museum of Illusions          Museum
# 12                  Museum at Eldridge Street          Museum
# 13                              Museum of Sex   Erotic Museum
# ...

# %%
# delete unnecessary columns
clean_Museum_dataframe2= clean_Museum_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Museum_dataframe2
# Out:
#                                                  name  \
# 0             National September 11 Memorial & Museum
# 1                      Whitney Museum of American Art
# 2                           Museum of Jewish Heritage
# 3               National September 11 Memorial Museum
# 4              National Museum of the American Indian
# 5                                          New Museum
# 6                 Museum of Chinese in America (MOCA)
# 7                     Ellis Island Immigration Museum
# 8                                     Tenement Museum
# 9           Leslie+Lohman Museum of Gay & Lesbian Art
# 10                        South Street Seaport Museum
# 11                                Museum of Illusions
# 12                          Museum at Eldridge Street
# 13                                      Museum of Sex
# 14                          New York City Fire Museum
# 15                      Children's Museum of the Arts
# ...

# %%
df_Museum = clean_Museum_dataframe2[clean_Museum_dataframe2.categories == 'History Museum']
df_Museum
# Out:
#                                      name      categories            address  \
# 2               Museum of Jewish Heritage  History Museum      36 Battery Pl
# 3   National September 11 Memorial Museum  History Museum   180 Greenwich St
# 6     Museum of Chinese in America (MOCA)  History Museum      215 Centre St
# 7         Ellis Island Immigration Museum  History Museum       Ellis Island
# 8                         Tenement Museum  History Museum     103 Orchard St
# 10            South Street Seaport Museum  History Museum       12 Fulton St
# 22                New York Transit Museum  History Museum          Boerum Pl
# 24                Italian American Museum  History Museum    155 Mulberry St
# 25                   KGB Espionage Museum  History Museum      245 W 14th St
# 28                Merchant's House Museum  History Museum        29 E 4th St
# 32            9/11 Museum Concourse Lobby  History Museum   180 Greenwich St
# ...

# %%
# search for Art Gallery
search_query = 'Art Gallery'
radius = 3000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=MPT43K2CE4TIK1R40RWQ0HELP5HINYAZI4SHLXCZZJDA50VF&client_secret=TNYKF1QMC4AG3JIXK0M3WU1PYC1HD5VDWIP3RTXDFRLG2EAC&ll=40.7127281,-74.0060152&v=20180604&query=Art Gallery&radius=3000&limit=60'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
ArtGallery_dataframe = json_normalize(venues)
ArtGallery_dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...    False
# 1  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...    False
# 2  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...    False
# 3  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...    False
# 4  [{'id': '4bf58dd8d48988d1e2931735', 'name': 'A...    False
#
#                          id     location.address location.cc location.city  \
# 0  441274fdf964a520d1301fe3  100 Washington Sq E          US      New York
# 1  5b81b49395d986002cd099e9         66 Greene St          US      New York
# 2  4dfbdd54d4c001cca36a91c1       71 Franklin St          US      New York
# 3  4c647887cdb6e21e4b92323e        105 Nassau St          US      New York
# 4  4b999381f964a520df8435e3        74 Trinity Pl          US      New York
#
#   location.country location.crossStreet  location.distance  \
# 0    United States        Washington Pl               2147
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
ArtGallery_clean_columns = ['name', 'categories'] + [col for col in ArtGallery_dataframe.columns if col.startswith('location.')]+ ['id']
clean_ArtGallery_dataframe = ArtGallery_dataframe.loc[:,ArtGallery_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_ArtGallery_dataframe['categories'] = clean_ArtGallery_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_ArtGallery_dataframe.columns = [column.split('.')[-1] for column in clean_ArtGallery_dataframe.columns]

clean_ArtGallery_dataframe.head(15)
# Out:
#                                                  name              categories  \
# 0                                NYU Grey Art Gallery             Art Gallery
# 1                               C. J. Yao Art Gallery             Art Gallery
# 2                                  Tunney Art Gallery             Art Gallery
# 3                                     A&A Art Gallery             Art Gallery
# 4                             World Trade Art Gallery             Art Gallery
# 5                            Van Der Plas Art Gallery             Art Gallery
# 6                                     Koh Art Gallery             Art Gallery
# 7                             Living With Art Gallery             Art Gallery
# 8                                  Fulton Art Gallery  Furniture / Home Store
# 9                                  Fulton Art Gallery             Art Gallery
# 10  Tmnk/destroy Rebuild/ URnew-york Street Art Ga...             Art Gallery
# ...

# %%
# delete unnecessary columns
clean_ArtGallery_dataframe2= clean_ArtGallery_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_ArtGallery_dataframe2
# Out:
#                                                  name              categories  \
# 0                                NYU Grey Art Gallery             Art Gallery
# 1                               C. J. Yao Art Gallery             Art Gallery
# 2                                  Tunney Art Gallery             Art Gallery
# 3                                     A&A Art Gallery             Art Gallery
# 4                             World Trade Art Gallery             Art Gallery
# 5                            Van Der Plas Art Gallery             Art Gallery
# 6                                     Koh Art Gallery             Art Gallery
# 7                             Living With Art Gallery             Art Gallery
# 8                                  Fulton Art Gallery  Furniture / Home Store
# 9                                  Fulton Art Gallery             Art Gallery
# 10  Tmnk/destroy Rebuild/ URnew-york Street Art Ga...             Art Gallery
# ...

# %%
df_ArtGallery = clean_ArtGallery_dataframe2[clean_ArtGallery_dataframe2.categories == 'Art Gallery']
df_ArtGallery
# Out:
#                                                  name   categories  \
# 0                                NYU Grey Art Gallery  Art Gallery
# 1                               C. J. Yao Art Gallery  Art Gallery
# 2                                  Tunney Art Gallery  Art Gallery
# 3                                     A&A Art Gallery  Art Gallery
# 4                             World Trade Art Gallery  Art Gallery
# 5                            Van Der Plas Art Gallery  Art Gallery
# 6                                     Koh Art Gallery  Art Gallery
# 7                             Living With Art Gallery  Art Gallery
# 9                                  Fulton Art Gallery  Art Gallery
# 10  Tmnk/destroy Rebuild/ URnew-york Street Art Ga...  Art Gallery
# 11                        Petet Fingesten Art Gallery  Art Gallery
# 13                                  Decor Art Gallery  Art Gallery
# 14                            Orchid Art Gallery Inc.  Art Gallery
# ...

# %%
# search for JazzClub
search_query = 'Jazz'
radius = 3000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=MPT43K2CE4TIK1R40RWQ0HELP5HINYAZI4SHLXCZZJDA50VF&client_secret=TNYKF1QMC4AG3JIXK0M3WU1PYC1HD5VDWIP3RTXDFRLG2EAC&ll=40.7127281,-74.0060152&v=20180604&query=Jazz&radius=3000&limit=60'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Club_dataframe = json_normalize(venues)
Club_dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...         NaN
# 1  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...         NaN
# 2  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...         NaN
# 3  [{'id': '4bf58dd8d48988d199941735', 'name': 'C...         NaN
# 4  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...         NaN
#
#   delivery.provider.icon.name delivery.provider.icon.prefix  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.name delivery.url  hasPerk  \
# 0                          NaN                    NaN          NaN    False
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
Club_clean_columns = ['name', 'categories'] + [col for col in Club_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Club_dataframe = Club_dataframe.loc[:,Club_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Club_dataframe['categories'] = clean_Club_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Club_dataframe.columns = [column.split('.')[-1] for column in clean_Club_dataframe.columns]

clean_Club_dataframe.head()
# Out:
#                    name             categories        address  cc      city  \
# 0         Jazz Standard              Jazz Club  111 E 27th St  US  New York
# 1          Jazz Gallery              Jazz Club  1160 Broadway  US  New York
# 2         Jazz Club Hub              Jazz Club            NaN  US  New York
# 3  The New School- Jazz  College Arts Building   55 W 13th St  US  New York
# 4      Smalls Jazz Club              Jazz Club  183 W 10th St  US  New York
#
#          country               crossStreet  distance  \
# 0  United States  btw Park & Lexington Ave      3777
# 1  United States                 5th Floor      3841
# 2  United States                       NaN       139
# 3  United States                       NaN      2765
# 4  United States   btwn 4th St & 7th Ave S      2423
#
#                                     formattedAddress  \
# 0  [111 E 27th St (btw Park & Lexington Ave), New...
# 1  [1160 Broadway (5th Floor), New York, NY 10001...
# ...

# %%
# delete unnecessary columns
clean_Club_dataframe2= clean_Club_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Club_dataframe2
# Out:
#                                                  name             categories  \
# 0                                       Jazz Standard              Jazz Club
# 1                                        Jazz Gallery              Jazz Club
# 2                                       Jazz Club Hub              Jazz Club
# 3                                The New School- Jazz  College Arts Building
# 4                                    Smalls Jazz Club              Jazz Club
# 5                             Jazz on the Town Hostel                 Hostel
# 6                                             NY Jazz              Jazz Club
# 7                                            Jazz Spa                    Spa
# 8                                  Jazz Brunch Cruise                 Cruise
# 9                                  Jazz Record Center            Record Shop
# 10                                   Jazz On The Pier           Concert Hall
# ...

# %%
df_Club = clean_Club_dataframe2[clean_Club_dataframe2.categories == 'Jazz Club']
df_Club
# Out:
#                    name categories             address        lat        lng  \
# 0         Jazz Standard  Jazz Club       111 E 27th St  40.742252 -73.983937
# 1          Jazz Gallery  Jazz Club       1160 Broadway  40.744666 -73.988756
# 2         Jazz Club Hub  Jazz Club                 NaN  40.712786 -74.004360
# 4      Smalls Jazz Club  Jazz Club       183 W 10th St  40.734358 -74.002789
# 6               NY Jazz  Jazz Club                 NaN  40.707199 -74.010002
# 11             WMC Jazz  Jazz Club     367 Bedford Ave  40.711252 -73.963282
# 17            Blue Note  Jazz Club        131 W 3rd St  40.730833 -74.000808
# 21          Parlor Jazz  Jazz Club  119 Vanderbilt Ave  40.695738 -73.971470
# 27              Mezzrow  Jazz Club       163 W 10th St  40.734470 -74.001900
# 28  Jazzhaus Breuckelen  Jazz Club                 NaN  40.694579 -73.982943
# 31               55 Bar  Jazz Club   55 Christopher St  40.733779 -74.002249
#
#    neighborhood postalCode state
# ...

# %% [markdown]
# Machine learning technique- Clustering will help to plan an itinerary for tourists

# %% [markdown]
# PART 1 - Generate map to visualize hotels, shopping stores  and Cafeteria to show how they cluster together

# %%
# create dataframe of hotels, shopping stores and Cafeteria
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Mall], ignore_index=True)
hotel_neighbourhood_df
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   from ipykernel import kernelapp as app
#                  address           categories        lat        lng  \
# 0          85 W Broadway                Hotel  40.715144 -74.009183
# 1          27 Barclay St                Hotel  40.712612 -74.009380
# 2          95 W Broadway                Hotel  40.715622 -74.009115
# 3          95 W Broadway                Hotel  40.715675 -74.009047
# 4       95 West Broadway                Hotel  40.715460 -74.009383
# 5           55 Church St                Hotel  40.711114 -74.010333
# 6   270 Greenwich Street        Grocery Store  40.715579 -74.011368
# ...

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)

# %%
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
#  Part 2- Generate map to visualize park, Restaurant and cafeteria stores to show how they cluster together

# %%
# create dataframe of Park, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   from ipykernel import kernelapp as app
#                        address                     categories        lat  \
# 0                      Main St                           Park  40.702282
# 1                    E 42nd St                           Park  40.753621
# 2                  Hudson Blvd                           Park  40.755580
# 3                 120 Cedar St                            Pub  40.709894
# 4              20 Elizabeth St             Dim Sum Restaurant  40.715881
# 5              126 Chambers St                    Wings Joint  40.715336
# 6                18 E Broadway             Dim Sum Restaurant  40.713629
# ...

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# PART 3- Generate map to visualize Museum, Art Gallery, Restaurant and Cafeteria to show how they cluster together

# %%
# create dataframe of Museum, Art Gallery, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_Museum,df_ArtGallery, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   from ipykernel import kernelapp as app
#                                address                     categories  \
# 0                        36 Battery Pl                 History Museum
# 1                     180 Greenwich St                 History Museum
# 2                        215 Centre St                 History Museum
# 3                         Ellis Island                 History Museum
# 4                       103 Orchard St                 History Museum
# 5                         12 Fulton St                 History Museum
# 6                            Boerum Pl                 History Museum
# ...

# %%
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# PART 4- Generate map to visualize Theater, Club, Restaurant and Cafeteria to show how they cluster together

# %%
# create dataframe of Theater, Club, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_Theater,df_Club, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   from ipykernel import kernelapp as app
#                        address                     categories        lat  \
# 0                 20 Thomas St                        Theater  40.716161
# 1    32 Avenue of the Americas                        Theater  40.720054
# 2                  89 South St                        Theater  40.708816
# 3                          NaN                        Theater  40.712983
# 4                          NaN                        Theater  40.718046
# 5                279 Church St                        Theater  40.718804
# 6                    45 Bowery                        Theater  40.714898
# ...

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Results:
#
# After clustering the data of the respective neighborhoods, all Boroughs have venues which can be explored and attract the Tourists. The neighborhoods are much similar in features like Theater, club houses, food places, clubs, museums, parks etc. This data segmentation and clustering based on things to do for tourist have helped to draft an itinerary. By covering Day 1 major sightseeing Parks, Day 2 to visit museums, Art gallery etc., Day 3 to cover Theater, concerts and Jazz clubs, finally on day 4 spends on Shopping. All these days using the data the respective neighborhood restaurants and cafeterias can be located for human fuel.

# %% [markdown]
# Conclusion:
#
# The neighborhoods in New York have more unique places to visit in course of four days. As we know that every place is unique in its own way, so plan to cover all famous tourist areas is very critical and we were able to come up with an itinerary for the tourists based on this detailed data.
